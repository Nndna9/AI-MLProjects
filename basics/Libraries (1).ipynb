# %% [markdown]
# # Librabies you must know

# %% [markdown]
# Python is one of the most popular programming languages for this task and it has replaced many languages in the industry, one of the reasons is its vast collection of libraries. lt's look at some of them you'll usually use in AI/ML, data analysis or data science.

# %% [markdown]
# 1. **NumPy**
#
#  It is a very popular and most used python library for large multi-dimensional array and matrix processing, with the help of a large collection of high-level mathematical functions. It is very useful for fundamental scientific computations in Machine Learning. You can do many maths basic stuff using NumPy easily.

# %%
#basic mathematical operations using NumPy

import numpy as np

# Creating two arrays of rank 2
x = np.array([[1, 2], [3, 4]])
y = np.array([[5, 6], [7, 8]])

# Creating two arrays of rank 1
v = np.array([9, 10])
w = np.array([11, 12])

# Inner product of vectors
print(np.dot(v, w), "\n")

# Matrix and Vector product
print(np.dot(x, v), "\n")

# Matrix and matrix product
print(np.dot(x, y))
# Out:
# 219
#
# [29 67]
#
# [[19 22]
#  [43 50]]

# %%
# Python Program to create a data type object
import numpy as np

# First Array
arr1 = np.array([[4, 7], [2, 6]],
                 dtype = np.float64)

# Second Array
arr2 = np.array([[3, 6], [2, 8]],
                 dtype = np.float64)

# Addition of two Arrays
Sum = np.add(arr1, arr2)
print("Addition of Two Arrays: ")
print(Sum)

# Addition of all Array elements
# using predefined sum method
Sum1 = np.sum(arr1)
print("\nAddition of Array elements: ")
print(Sum1)

# Square root of Array
Sqrt = np.sqrt(arr1)
print("\nSquare root of Array1 elements: ")
print(Sqrt)

# Transpose of Array
# using In-built function 'T'
Trans_arr = arr1.T
print("\nTranspose of Array: ")
print(Trans_arr)
# Out:
# Addition of Two Arrays:
# [[ 7. 13.]
#  [ 4. 14.]]
#
# Addition of Array elements:
# 19.0
#
# Square root of Array1 elements:
# [[2.         2.64575131]
#  [1.41421356 2.44948974]]
#
# Transpose of Array:
# [[4. 2.]
#  [7. 6.]]

# %% [markdown]
#  **2. pandas**
#
# It is a very popular library in Python used for working with data sets.
# It has functions for analyzing, cleaning, exploring, and manipulating data.
# Pandas gives you answers about the data. Like:
#
# Is there a correlation between two or more columns?
#
# What is average value?
#
# Max value?
#
# Min value?
#
# Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or NULL values. This is called cleaning the data.

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# **3. Scikit-learn**
#
# This one is one of the most popular ML libraries for classical ML algorithms. It is built on top of two basic Python libraries, viz., NumPy and SciPy. Scikit-learn supports most of the supervised and unsupervised learning algorithms. Scikit-learn can also be used for data-mining and data-analysis, which makes it a great tool who is starting out with ML.

# %%
# Sample Decision Tree Classifier
from sklearn import datasets
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier

# load the iris datasets
dataset = datasets.load_iris()

# fit a CART model to the data
model = DecisionTreeClassifier()
model.fit(dataset.data, dataset.target)
print(model)

# make predictions
expected = dataset.target
predicted = model.predict(dataset.data)

# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00        50
#            2       1.00      1.00      1.00        50
#
#     accuracy                           1.00       150
#    macro avg       1.00      1.00      1.00       150
# weighted avg       1.00      1.00      1.00       150
#
# [[50  0  0]
#  [ 0 50  0]
#  [ 0  0 50]]

# %% [markdown]
# **4. Mathplotlib**
#
# Matplotlib is widely recognized as a Python library indispensable for data visualization. While it shares a similarity with Pandas in not being directly tied to Machine Learning, it serves a crucial purpose in revealing patterns within data. This 2D plotting library is adept at crafting graphs and plots, aiding programmers in visually representing data trends. The module pyplot simplifies the plotting process by offering features to manipulate line styles, font properties, and axis formatting, among others. Matplotlib offers a diverse range of graphs and plots for data visualization purposes, including histograms, error charts, bar charts, and more.

# %%
# importing the necessary packages and modules
import matplotlib.pyplot as plt
import numpy as np

# Prepare the data
x = np.linspace(0, 10, 100)

# Plot the data
plt.plot(x, x, label ='linear')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# **5.Scipy**
#
# SciPy, short for Scientific Python, is a scientific computation library built upon NumPy, leveraging its functionality at its core. Offering an extensive array of utility functions, SciPy specializes in optimization, statistics, and signal processing. Much like NumPy, SciPy is freely available as an open-source library, enabling its widespread usage. Notably, SciPy was developed by Travis Oliphant, the creator of NumPy. It has been optimized and enriched with additional functions commonly employed in NumPy and Data Science workflows.

# %%
import numpy as np
from scipy.sparse.csgraph import connected_components
from scipy.sparse import csr_matrix

arr = np.array([
  [0, 1, 2],
  [1, 0, 0],
  [2, 0, 0]
])

newarr = csr_matrix(arr)

print(connected_components(newarr))
# Out:
# (1, array([0, 0, 0], dtype=int32))

# %% [markdown]
# **6. Keras**
#
# It provides many inbuilt methods for groping, combining and filtering data.
# Keras is a very popular Machine Learning library for Python. It is a high-level neural networks API capable of running on top of TensorFlow, CNTK, or Theano. It can run seamlessly on both CPU and GPU. Keras makes it really for ML beginners to build and design a Neural Network. One of the best thing about Keras is that it allows for easy and fast prototyping.It cannot handle low-level computations, so it makes use of the Backend library to resolve it. The backend library act as a high-level API wrapper for the low-level API, which lets it run on TensorFlow, CNTK, or Theano
#
#
# We'll be learning more about this while working on big projects so right now we'll just see how we can import the librabries.

# %%
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# Ellipsis

# %% [markdown]
# **7. PyTorch**
#
# PyTorch stands out as a well-known open-source Machine Learning library for Python, built on the foundation of Torch, another open-source Machine Learning library implemented in C with a Lua wrapper. It boasts a wide array of tools and libraries supporting various domains such as Computer Vision, Natural Language Processing (NLP), and beyond in the realm of Machine Learning programs. PyTorch facilitates computations on Tensors with GPU acceleration, and it aids in the creation of computational graphs, providing developers with a robust framework for building and experimenting with Machine Learning models.

# %%
import torch
import math


dtype = torch.float
device = torch.device("cpu")
# device = torch.device("cuda:0") # Uncomment this to run on GPU

# Create random input and output data
x = torch.linspace(-math.pi, math.pi, 2000, device=device, dtype=dtype)
y = torch.sin(x)

# Randomly initialize weights
a = torch.randn((), device=device, dtype=dtype)
b = torch.randn((), device=device, dtype=dtype)
c = torch.randn((), device=device, dtype=dtype)
d = torch.randn((), device=device, dtype=dtype)

learning_rate = 1e-6
for t in range(2000):
    # Forward pass: compute predicted y
    y_pred = a + b * x + c * x ** 2 + d * x ** 3

    # Compute and print loss
    loss = (y_pred - y).pow(2).sum().item()
    if t % 100 == 99:
        print(t, loss)

    # Backprop to compute gradients of a, b, c, d with respect to loss
    grad_y_pred = 2.0 * (y_pred - y)
    grad_a = grad_y_pred.sum()
    grad_b = (grad_y_pred * x).sum()
    grad_c = (grad_y_pred * x ** 2).sum()
    grad_d = (grad_y_pred * x ** 3).sum()

    # Update weights using gradient descent
    a -= learning_rate * grad_a
    b -= learning_rate * grad_b
    c -= learning_rate * grad_c
    d -= learning_rate * grad_d


print(f'Result: y = {a.item()} + {b.item()} x + {c.item()} x^2 + {d.item()} x^3')
# Out:
# 99 847.8092651367188
# 199 581.864013671875
# 299 400.6695251464844
# 399 277.075927734375
# 499 192.6759033203125
# 599 134.9739990234375
# 699 95.4797134399414
# 799 68.41644287109375
# 899 49.85035705566406
# 999 37.09894561767578
# 1099 28.331348419189453
# 1199 22.29615020751953
# 1299 18.1372127532959
# 1399 15.268099784851074
# 1499 13.286670684814453
# 1599 11.916864395141602
# 1699 10.96891975402832
# 1799 10.312239646911621
# 1899 9.856902122497559
# 1999 9.540873527526855
# Result: y = -0.024860508739948273 + 0.8439891934394836 x + 0.004288852214813232 x^2 + -0.09151657670736313 x^3

# %% [markdown]
# **8. Scrapy**
#
# Another notable Python library in the realm of data science is Scrapy. Renowned for its speed and popularity, Scrapy is an open-source web crawling framework written in Python. Its primary function is to facilitate data extraction from web pages using selectors based on XPath. Scrapy simplifies the creation of crawling programs, commonly referred to as spider bots, enabling the retrieval of structured data from the web. Moreover, it extends its utility to gathering data from APIs. Scrapy adheres to the 'Don't Repeat Yourself' (DRY) principle in its interface design, encouraging users to craft universal code snippets that can be reused for constructing and scaling extensive crawlers. Lets see how we can insall Scarpy.

# %%
# !pip install scrapy
# Out:
# ...
#      |████████████████████████████████| 235kB 2.8MB/s
# ...
#      |████████████████████████████████| 3.1MB 43.2MB/s
# ...
#      |████████████████████████████████| 61kB 22.3MB/s
# ...
#      |████████████████████████████████| 174kB 41.3MB/s
# ...
#      |████████████████████████████████| 61kB 19.8MB/s
# ...
#      |████████████████████████████████| 2.3MB 37.0MB/s
# ...
#      |████████████████████████████████| 102kB 27.2MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
# ...
#   Stored in directory: /root/.cache/pip/wheels/57/c0/6c/874eb1b6a5ab9ac5434ab9d2700cf78fed3c151ea33cf668af
# Successfully built PyDispatcher Twisted
# ...

# %% [markdown]
# **9. Seaborn**
#
# Seaborn simplifies the process of creating complex statistical visualizations by providing a high-level interface. It offers a variety of plot types and customization options, allowing users to effectively communicate insights from their data. Additionally, Seaborn seamlessly integrates with Pandas data structures, further enhancing its utility in data analysis workflows.

# %%
# importing packages
import seaborn as sns

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# setting the x limit of the plot
plt.xlim(5)

plt.show()

# %% [markdown]
# ## We'll look at other libraries as we start with respected projects.
